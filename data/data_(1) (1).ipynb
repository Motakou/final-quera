# %% [markdown]
# import

# %%
# !pip install adjustText
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import adjustText
data=pd.read_csv("/content/imdb_movies.csv")
df=pd.DataFrame(data)
# Out:
# Collecting adjustText
#   Downloading adjustText-1.0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from adjustText) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from adjustText) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from adjustText) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->adjustText) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.16.0)
# Installing collected packages: adjustText
# Successfully installed adjustText-1.0.4

# %%
# Out:
#   File "<ipython-input-7-43f430882583>", line 3
#     import pandas as pd
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# سوال یک: با رسم نمودار نشان دهید در هرسال چند فیلم سینمایی منتشر شده است؟

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from adjustText import adjust_text
data=pd.read_csv("/content/imdb_movies.csv")
df=pd.DataFrame(data)
filtered_df = df[df['runtime'] > 30]
film_count_by_year = filtered_df['release_year'].value_counts().sort_index()
film_count_df = pd.DataFrame({'Year': film_count_by_year.index, 'Number of Films': film_count_by_year.values})
print(film_count_df)
# Out:
#     Year  Number of Films
# 0   1960               32
# 1   1961               31
# 2   1962               32
# 3   1963               33
# 4   1964               41
# 5   1965               34
# 6   1966               43
# 7   1967               39
# 8   1968               36
# 9   1969               29
# 10  1970               41
# 11  1971               55
# 12  1972               40
# 13  1973               54
# 14  1974               46
# 15  1975               44
# 16  1976               47
# 17  1977               57
# 18  1978               65
# 19  1979               57
# 20  1980               78
# 21  1981               82
# 22  1982               79
# 23  1983               78
# 24  1984              103
# 25  1985              109
# 26  1986              119
# 27  1987              124
# 28  1988              144
# 29  1989              136
# 30  1990              131
# 31  1991              133
# 32  1992              132
# 33  1993              176
# 34  1994              183
# 35  1995              174
# 36  1996              203
# 37  1997              190
# 38  1998              210
# 39  1999              224
# 40  2000              221
# 41  2001              240
# 42  2002              263
# 43  2003              267
# 44  2004              304
# 45  2005              357
# 46  2006              399
# 47  2007              431
# 48  2008              483
# 49  2009              517
# 50  2010              468
# 51  2011              513
# 52  2012              570
# 53  2013              635
# 54  2014              685
# 55  2015              608

# %% [markdown]
# سوال دوم: با رسم نمودار روند تعداد سینمایی انتشار رفته را نشان دهید

# %%
filtered_df9 = df[df['runtime'] >= 30]
film_count_by_year = filtered_df9['release_year'].value_counts().sort_index()
plt.figure(figsize=(12, 6))
plt.bar(film_count_by_year.index, film_count_by_year.values, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Number of Films')
plt.title('Number of Films Released in Each Year (excluding films under 30m runtime)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# سوال سه: میانگین طول فیل مهای سینمایی در طول همه سالها بطور میانگین چه مقدار بوده است ؟

# %%
df_filtered1 = df[df['runtime'] > 30]
mean_runtime = df_filtered1['runtime'].mean()
print("Mean Runtime For All Years (Excluding under 30 values):", mean_runtime)
# Out:
# Mean Runtime For All Years (Excluding under 30 values): 104.13308235294117

# %% [markdown]
# سوال چهار: میانگین طول فیل مهای سینمایی در هر سال چند دقیقه بوده است؟ پاسخ را به ساعت و دقیقه نمایش
# دهید .

# %%
filtered_df34 = df[df['runtime'] >= 30]
mean_runtime_by_year = filtered_df34.groupby('release_year')['runtime'].mean().sort_index()
print("Mean runtime of films in each year (excluding films under 30m runtime):")
for year, mean_runtime in mean_runtime_by_year.items():
    hours = int(mean_runtime // 60)
    minutes = int(mean_runtime % 60)
    print(f"Year: {year} - Mean Runtime: {hours} hours {minutes} minutes")
# Out:
# Mean runtime of films in each year (excluding films under 30m runtime):
# Year: 1960 - Mean Runtime: 1 hours 50 minutes
# Year: 1961 - Mean Runtime: 1 hours 59 minutes
# Year: 1962 - Mean Runtime: 2 hours 4 minutes
# Year: 1963 - Mean Runtime: 1 hours 54 minutes
# Year: 1964 - Mean Runtime: 1 hours 51 minutes
# Year: 1965 - Mean Runtime: 2 hours 0 minutes
# Year: 1966 - Mean Runtime: 1 hours 52 minutes
# Year: 1967 - Mean Runtime: 1 hours 47 minutes
# Year: 1968 - Mean Runtime: 1 hours 55 minutes
# Year: 1969 - Mean Runtime: 1 hours 53 minutes
# Year: 1970 - Mean Runtime: 1 hours 52 minutes
# Year: 1971 - Mean Runtime: 1 hours 47 minutes
# Year: 1972 - Mean Runtime: 1 hours 41 minutes
# Year: 1973 - Mean Runtime: 1 hours 44 minutes
# Year: 1974 - Mean Runtime: 1 hours 47 minutes
# Year: 1975 - Mean Runtime: 1 hours 47 minutes
# Year: 1976 - Mean Runtime: 1 hours 49 minutes
# Year: 1977 - Mean Runtime: 1 hours 47 minutes
# Year: 1978 - Mean Runtime: 1 hours 50 minutes
# Year: 1979 - Mean Runtime: 1 hours 52 minutes
# Year: 1980 - Mean Runtime: 1 hours 47 minutes
# Year: 1981 - Mean Runtime: 1 hours 45 minutes
# Year: 1982 - Mean Runtime: 1 hours 46 minutes
# Year: 1983 - Mean Runtime: 1 hours 45 minutes
# Year: 1984 - Mean Runtime: 1 hours 45 minutes
# Year: 1985 - Mean Runtime: 1 hours 54 minutes
# Year: 1986 - Mean Runtime: 1 hours 41 minutes
# Year: 1987 - Mean Runtime: 1 hours 41 minutes
# Year: 1988 - Mean Runtime: 1 hours 42 minutes
# Year: 1989 - Mean Runtime: 1 hours 45 minutes
# Year: 1990 - Mean Runtime: 1 hours 46 minutes
# Year: 1991 - Mean Runtime: 1 hours 45 minutes
# Year: 1992 - Mean Runtime: 1 hours 47 minutes
# Year: 1993 - Mean Runtime: 1 hours 47 minutes
# Year: 1994 - Mean Runtime: 1 hours 47 minutes
# Year: 1995 - Mean Runtime: 1 hours 47 minutes
# Year: 1996 - Mean Runtime: 1 hours 46 minutes
# Year: 1997 - Mean Runtime: 1 hours 47 minutes
# Year: 1998 - Mean Runtime: 1 hours 45 minutes
# Year: 1999 - Mean Runtime: 1 hours 48 minutes
# Year: 2000 - Mean Runtime: 1 hours 45 minutes
# Year: 2001 - Mean Runtime: 1 hours 48 minutes
# Year: 2002 - Mean Runtime: 1 hours 48 minutes
# Year: 2003 - Mean Runtime: 1 hours 45 minutes
# Year: 2004 - Mean Runtime: 1 hours 45 minutes
# Year: 2005 - Mean Runtime: 1 hours 44 minutes
# Year: 2006 - Mean Runtime: 1 hours 43 minutes
# Year: 2007 - Mean Runtime: 1 hours 41 minutes
# Year: 2008 - Mean Runtime: 1 hours 42 minutes
# Year: 2009 - Mean Runtime: 1 hours 40 minutes
# Year: 2010 - Mean Runtime: 1 hours 41 minutes
# Year: 2011 - Mean Runtime: 1 hours 42 minutes
# Year: 2012 - Mean Runtime: 1 hours 40 minutes
# Year: 2013 - Mean Runtime: 1 hours 39 minutes
# Year: 2014 - Mean Runtime: 1 hours 40 minutes
# Year: 2015 - Mean Runtime: 1 hours 39 minutes

# %% [markdown]
# سوال پنج: طولانی ترین و کوتاه ترین فیلم ثبت شده،‌کدام فیلم ها بوده است؟

# %%
df_filtered = df[df['runtime'] > 30]
max_runtime_row = df_filtered[df_filtered['runtime'] == df_filtered['runtime'].max()]
min_runtime_row = df_filtered[df_filtered['runtime'] == df_filtered['runtime'].min()]
print("Movie with the highest runtime:")
print(f"{max_runtime_row['original_title'].iloc[0]} (Runtime: {max_runtime_row['runtime'].iloc[0]} minutes)")
print("\nMovie with the lowest runtime:")
print(f"{min_runtime_row['original_title'].iloc[0]} (Runtime: {min_runtime_row['runtime'].iloc[0]} minutes)")
# Out:
# Movie with the highest runtime:
# The Story of Film: An Odyssey (Runtime: 900 minutes)
#
# Movie with the lowest runtime:
# Kung Fury (Runtime: 31 minutes)

# %% [markdown]
# سوال شش: طولانی ترین و کوتاه ترین فیلم برای هر سال، کدام فیلم بوده است؟

# %%
dfff = df[df['runtime'] > 30]
mini=dfff.groupby("release_year")["runtime"].min()

maxi=dfff.groupby("release_year")["runtime"].max()
mini=mini.reset_index()
maxi=maxi.reset_index()
date=list()
mini_list=list()
maxi_list=list()
for i in mini["runtime"]:
    mini_list.append(i)
for i in maxi["runtime"]:
    maxi_list.append(i)
for i in maxi["release_year"]:
    date.append(i)
dataa=list(zip(date,mini_list,maxi_list))
dff=pd.DataFrame(dataa,columns=["date","min","max"])
print(dff)
# Out:
#     date  min  max
# 0   1960   70  208
# 1   1961   79  186
# 2   1962   78  216
# 3   1963   79  248
# 4   1964   52  170
# 5   1965   80  199
# 6   1966   74  182
# 7   1967   55  152
# 8   1968   86  155
# 9   1969   85  158
# 10  1970   48  225
# 11  1971   73  189
# 12  1972   78  175
# 13  1973   74  151
# 14  1974   51  200
# 15  1975   72  184
# 16  1976   80  139
# 17  1977   48  177
# 18  1978   76  183
# 19  1979   78  184
# 20  1980   74  219
# 21  1981   55  195
# 22  1982   76  191
# 23  1983   69  197
# 24  1984   77  229
# 25  1985   77  566
# 26  1986   74  142
# 27  1987   36  230
# 28  1988   43  180
# 29  1989   78  372
# 30  1990   71  192
# 31  1991   75  236
# 32  1992   61  202
# 33  1993   60  254
# 34  1994   69  366
# 35  1995   53  300
# 36  1996   73  242
# 37  1997   54  273
# 38  1998   44  182
# 39  1999   33  257
# 40  2000   48  417
# 41  2001   65  705
# 42  2002   42  877
# 43  2003   49  352
# 44  2004   34  360
# 45  2005   47  240
# 46  2006   32  550
# 47  2007   48  270
# 48  2008   32  501
# 49  2009   36  500
# 50  2010   44  540
# 51  2011   40  900
# 52  2012   41  389
# 53  2013   44  400
# 54  2014   41  285
# 55  2015   31  300

# %% [markdown]
# سوال هفت: با استفاده از نمودار هیستوگرام، توزیع مدت زمان فیلم ها در طول تاریخ را بکشید

# %%
filtered_df = df[df['runtime'] >= 30]
mean_runtime_by_year = filtered_df.groupby('release_year')['runtime'].mean().sort_index()
plt.figure(figsize=(12, 6))
plt.bar(mean_runtime_by_year.index, mean_runtime_by_year, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Mean Runtime (in minutes)')
plt.title('Mean Runtime of Films per Year (excluding films under 30m runtime)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# سوال هشت: میانگین بودجه اختصاص یافته به فیلم ها در طول تاریخ چه مقدار بوده است؟

# %%
df_filtered2 = df[df['budget_adj'] > 5000]
mean_budget = df_filtered2['budget_adj'].mean()
print("Mean budget_adj For All Years (Excluding under 5000 values):", mean_budget)
# Out:
# Mean budget_adj For All Years (Excluding under 5000 values): 37335469.71462281

# %% [markdown]
# سوال نه: میانگین درآمد اختصاص یافته به فیلم ها در طول تاریخ چه مقدار بوده است؟

# %%
df_filtered3 = df[df['revenue_adj'] > 5000]
mean_revenue = df_filtered3['revenue_adj'].mean()
print("Mean revenue_adj For All Years (excluding under 5000 values):", mean_revenue)
# Out:
# Mean revenue_adj For All Years (excluding under 5000 values): 116762575.13198702

# %% [markdown]
# سوال ده: میانگین بودجه و درآمد اختصاص یافته در هر سال چه مقدار بوده است؟

# %%
dff=df[df["budget_adj"] > 5000]
dff=dff[dff["revenue_adj"] > 5000]
mean_bod=dff.groupby("release_year")["budget_adj"].mean()
mean_rev=dff.groupby("release_year")["revenue_adj"].mean()
mean_bod=mean_bod.reset_index()
mean_rev=mean_rev.reset_index()
rev_list=list()
bod_list=list()
date=list()
for i in mean_bod["budget_adj"]:
    bod_list.append(i)
for i in mean_rev["revenue_adj"]:
    rev_list.append(i)
for i in mean_rev["release_year"]:
    date.append(i)

dataa=list(zip(date,bod_list,rev_list))
dff=pd.DataFrame(dataa,columns=["date","mean_bud","mean_rev"])
print(dff)
# Out:
#     date      mean_bud      mean_rev
# 0   1960  3.068179e+07  1.902299e+08
# 1   1961  2.818516e+07  2.463622e+08
# 2   1962  4.062476e+07  2.124740e+08
# 3   1963  7.252496e+07  2.094838e+08
# 4   1964  3.408189e+07  3.300344e+08
# 5   1965  8.138583e+07  6.340369e+08
# 6   1966  4.335538e+07  1.138525e+08
# 7   1967  4.802007e+07  3.679869e+08
# 8   1968  3.757895e+07  1.547889e+08
# 9   1969  3.394782e+07  3.413599e+08
# 10  1970  4.896551e+07  2.808041e+08
# 11  1971  1.657066e+07  1.558752e+08
# 12  1972  1.542484e+07  3.134604e+08
# 13  1973  2.346184e+07  4.563339e+08
# 14  1974  2.367112e+07  2.449833e+08
# 15  1975  1.670251e+07  3.805593e+08
# 16  1976  3.078131e+07  1.915661e+08
# 17  1977  2.629221e+07  3.563997e+08
# 18  1978  3.471604e+07  2.447003e+08
# 19  1979  4.332191e+07  2.217793e+08
# 20  1980  3.682018e+07  1.521029e+08
# 21  1981  2.332241e+07  1.288629e+08
# 22  1982  3.108364e+07  1.948405e+08
# 23  1983  3.426817e+07  1.405610e+08
# 24  1984  2.863928e+07  1.202694e+08
# 25  1985  3.021874e+07  1.143562e+08
# 26  1986  2.662842e+07  9.224712e+07
# 27  1987  2.540404e+07  1.150396e+08
# 28  1988  2.632559e+07  1.011512e+08
# 29  1989  3.338586e+07  1.576854e+08
# 30  1990  3.915796e+07  1.522145e+08
# 31  1991  4.215122e+07  1.425666e+08
# 32  1992  3.557618e+07  1.491386e+08
# 33  1993  3.491061e+07  1.371068e+08
# 34  1994  4.315594e+07  1.547797e+08
# 35  1995  4.846739e+07  1.529187e+08
# 36  1996  4.853806e+07  1.262532e+08
# 37  1997  6.080297e+07  1.571064e+08
# 38  1998  5.746289e+07  1.341499e+08
# 39  1999  5.647042e+07  1.303424e+08
# 40  2000  5.780982e+07  1.308101e+08
# 41  2001  5.319091e+07  1.348360e+08
# 42  2002  5.201025e+07  1.386445e+08
# 43  2003  5.509192e+07  1.495165e+08
# 44  2004  5.250512e+07  1.303551e+08
# 45  2005  4.679254e+07  1.102205e+08
# 46  2006  4.396997e+07  1.007016e+08
# 47  2007  4.468345e+07  1.202687e+08
# 48  2008  4.342388e+07  1.156830e+08
# 49  2009  4.428585e+07  1.269451e+08
# 50  2010  4.771426e+07  1.225018e+08
# 51  2011  4.195282e+07  1.163563e+08
# 52  2012  4.698199e+07  1.501244e+08
# 53  2013  4.505540e+07  1.280508e+08
# 54  2014  4.127475e+07  1.343675e+08
# 55  2015  4.123195e+07  1.506667e+08

# %% [markdown]
# سوال یازده: با پیدا کردن میانگین بودجه و درآمد برای هر سال، رابطه بین بودجه و درآمد را با استفاده از نمودار اسکتر را درطول سال های ثبت شده رسم کنید

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from adjustText import adjust_text
data=pd.read_csv("/content/imdb_movies.csv")
filtered_df = df[(df['budget_adj'] > 5000) & (df['revenue_adj'] > 5000)]
mean_budget_by_year = filtered_df.groupby('release_year')['budget_adj'].mean()
mean_revenue_by_year = filtered_df.groupby('release_year')['revenue_adj'].mean()
plt.figure(figsize=(12, 6))
scatter = plt.scatter(mean_budget_by_year, mean_revenue_by_year, color='skyblue', edgecolors='black')
plt.xlabel('Mean Budget (adjusted) in USD')
plt.ylabel('Mean Revenue (adjusted) in USD')
plt.title('Relationship between Mean Budget and Mean Revenue per Year')
plt.grid(True)
texts = [plt.text(x, y, str(year)) for x, y, year in zip(mean_budget_by_year, mean_revenue_by_year, mean_budget_by_year.index)]
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='red'))
plt.tight_layout()
plt.show()

# %% [markdown]
# سوال دوازده: با استفاده از ستون ژانر ها، و استخراج متن داخل این ستون ها، توزیع ژانر های تولید شده فیلم را بیابید. کدام ژانر بیشترین تعداد فیلم منتشر شده را دارد؟ نمودار میله ای آن را بکشید

# %%
genre_counts = df['genres'].value_counts()
top_20_genres = genre_counts.head(20)
print(f"Number of unique genres: {len(genre_counts)}")
most_used_genre = genre_counts.idxmax()
print(f"The most used genre: {most_used_genre} (Count: {genre_counts.max()})")
plt.figure(figsize=(12, 6))
top_20_genres.plot(kind='bar', color='skyblue')
plt.xlabel('Genres')
plt.ylabel('Count')
plt.title('Number of Films per Genre (Top 20)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Number of unique genres: 2039
# The most used genre: Comedy (Count: 712)

# %% [markdown]
# سوال سیزده: سود هر فیلم را محاسبه کنید. پر سودترین فیلم تاریخ چه فیلمی بوده است؟

# %%
df_filtered4 = df[(df['revenue_adj'] > 5000) & (df['budget_adj'] > 5000)]
df_filtered4['profit'] = df_filtered4['revenue_adj'] - df_filtered4['budget_adj']
max_profit_row = df_filtered4.loc[df_filtered4['profit'].idxmax()]
print("Movie with the highest profit:")
print("Title:", max_profit_row['original_title'])
print("Profit:", max_profit_row['profit'])
# Out:
# Movie with the highest profit:
# Title: Star Wars
# Profit: 2750136650.919176
# <ipython-input-20-01848825c1d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered4['profit'] = df_filtered4['revenue_adj'] - df_filtered4['budget_adj']

# %% [markdown]
# سوال چهاردم: پرسود ترین فیلم هر سال، کدام فیلم ها بوده است؟

# %%
filtered_df6 = df[(df['runtime'] >= 30) & (df['budget_adj'] >= 5000) & (df['revenue_adj'] >= 5000)]
filtered_df6['profit'] = filtered_df6['revenue_adj'] - filtered_df6['budget_adj']
max_profit_films = filtered_df6.loc[filtered_df6.groupby('release_year')['profit'].idxmax()]
print("Film with the highest profit for each year:")
for index, row in max_profit_films.iterrows():
    print(f"Year: {row['release_year']} - Film: {row['original_title']} - Profit: {row['profit']}")
# Out:
# Film with the highest profit for each year:
# Year: 1960 - Film: Spartacus - Profit: 353902437.9454192
# Year: 1961 - Film: One Hundred and One Dalmatians - Profit: 1545635294.8728774
# Year: 1962 - Film: Dr. No - Profit: 421694259.407566
# Year: 1963 - Film: From Russia With Love - Profit: 543972910.5655622
# Year: 1964 - Film: Goldfinger - Profit: 853474463.6081719
# Year: 1965 - Film: The Sound of Music - Profit: 1072786239.7047875
# Year: 1966 - Film: Who's Afraid of Virginia Woolf? - Profit: 176258462.17925608
# Year: 1967 - Film: The Jungle Book - Profit: 1319404004.0292516
# Year: 1968 - Film: 2001: A Space Odyssey - Profit: 280319033.8273269
# Year: 1969 - Film: Butch Cassidy and the Sundance Kid - Profit: 572485481.1346887
# Year: 1970 - Film: Love Story - Profit: 753716631.7515768
# Year: 1971 - Film: Diamonds Are Forever - Profit: 585909206.6907814
# Year: 1972 - Film: The Godfather - Profit: 1246626366.8015964
# Year: 1973 - Film: The Exorcist - Profit: 2128035624.5693455
# Year: 1974 - Film: Blazing Saddles - Profit: 516964986.56731206
# Year: 1975 - Film: Jaws - Profit: 1878643093.7113247
# Year: 1976 - Film: A Star Is Born - Profit: 593913194.4138436
# Year: 1977 - Film: Star Wars - Profit: 2750136650.919176
# Year: 1978 - Film: Superman - Profit: 819690439.1740379
# Year: 1979 - Film: Rocky II - Profit: 580426232.0399029
# Year: 1980 - Film: The Empire Strikes Back - Profit: 1376997526.2202368
# Year: 1981 - Film: Raiders of the Lost Ark - Profit: 891949443.7396424
# Year: 1982 - Film: E.T. the Extra-Terrestrial - Profit: 1767968064.0219922
# Year: 1983 - Film: Return of the Jedi - Profit: 1182994737.988604
# Year: 1984 - Film: Indiana Jones and the Temple of Doom - Profit: 640207821.9542158
# Year: 1985 - Film: Back to the Future - Profit: 734056616.720673
# Year: 1986 - Film: Top Gun - Profit: 680039989.0582647
# Year: 1987 - Film: Fatal Attraction - Profit: 587518210.6340469
# Year: 1988 - Film: Rain Man - Profit: 608162158.7833562
# Year: 1989 - Film: Indiana Jones and the Last Crusade - Profit: 749629788.1988637
# Year: 1990 - Film: Ghost - Profit: 806077994.9719423
# Year: 1991 - Film: Terminator 2: Judgment Day - Profit: 672458993.610679
# Year: 1992 - Film: Aladdin - Profit: 739793586.7283843
# Year: 1993 - Film: Jurassic Park - Profit: 1293766704.1719615
# Year: 1994 - Film: The Lion King - Profit: 1093391569.7363427
# Year: 1995 - Film: The Net - Profit: 1551568265.2760668
# Year: 1996 - Film: Independence Day - Profit: 1031498096.167681
# Year: 1997 - Film: Titanic - Profit: 2234713671.205051
# Year: 1998 - Film: Armageddon - Profit: 553537804.544767
# Year: 1999 - Film: Star Wars: Episode I - The Phantom Menace - Profit: 1059439453.0986631
# Year: 2000 - Film: Mission: Impossible II - Profit: 533600434.43949807
# Year: 2001 - Film: Harry Potter and the Philosopher's Stone - Profit: 1048582021.48035
# Year: 2002 - Film: The Lord of the Rings: The Two Towers - Profit: 1027133804.3211268
# Year: 2003 - Film: The Lord of the Rings: The Return of the King - Profit: 1214854861.8661132
# Year: 2004 - Film: Shrek 2 - Profit: 888736812.770198
# Year: 2005 - Film: Harry Potter and the Goblet of Fire - Profit: 832868045.778646
# Year: 2006 - Film: Pirates of the Caribbean: Dead Man's Chest - Profit: 936357520.2128761
# Year: 2007 - Film: Harry Potter and the Order of the Phoenix - Profit: 828938572.984591
# Year: 2008 - Film: The Dark Knight - Profit: 827367505.226985
# Year: 2009 - Film: Avatar - Profit: 2586236847.524277
# Year: 2010 - Film: Toy Story 3 - Profit: 863171911.0
# Year: 2011 - Film: Harry Potter and the Deathly Hallows: Part 2 - Profit: 1166009242.240936
# Year: 2012 - Film: The Avengers - Profit: 1234247693.3085759
# Year: 2013 - Film: Frozen - Profit: 1052306488.208787
# Year: 2014 - Film: The Hobbit: The Battle of the Five Armies - Profit: 649479526.4486699
# Year: 2015 - Film: Star Wars: The Force Awakens - Profit: 1718723210.761785
# <ipython-input-21-b8cef2a417c7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df6['profit'] = filtered_df6['revenue_adj'] - filtered_df6['budget_adj']

# %% [markdown]
# سوال پونزده:‌با استفاده از ستون محصولات کمپانی و استخراج متن داخل این ستون، کدام شرکت بیشترین فیلم را ساخته است؟

# %%
filtered_df5 = df[(df['runtime'] < 30) & (df['budget_adj'] < 5000) & (df['revenue_adj'] < 5000)]
production_companies_count = filtered_df5['production_companies'].value_counts()
print("Production company names and the number of their films:")
for company, count in production_companies_count.items():
    print(f"{company} - Number of Films: {count}")
most_repeated_company = production_companies_count.idxmax()
print("\nThe most repeated production company name:")
print(most_repeated_company)
# Out:
# Production company names and the number of their films:
# Pixar Animation Studios - Number of Films: 30
# DreamWorks Animation - Number of Films: 14
# Walt Disney Animation Studios - Number of Films: 5
# Walt Disney Pictures|Pixar Animation Studios - Number of Films: 4
# Illumination Entertainment - Number of Films: 4
# Studio 4Â°C - Number of Films: 4
# Blue Sky Studios - Number of Films: 4
# Walt Disney Pictures - Number of Films: 3
# Walt Disney Pictures|Walt Disney Animation Studios - Number of Films: 3
# Universal Pictures|Illumination Entertainment - Number of Films: 3
# Marvel Studios - Number of Films: 3
# Pensylvania Academy of Fine Arts - Number of Films: 2
# Rankin/Bass Productions - Number of Films: 2
# Walt Disney - Number of Films: 2
# DC Comics|Warner Bros. Animation - Number of Films: 2
# Magic Light Pictures - Number of Films: 2
# Warner Bros. Home Video - Number of Films: 2
# Bitter Films - Number of Films: 2
# Directions Inc. - Number of Films: 1
# NBV Productions - Number of Films: 1
# Melodrama Pictures - Number of Films: 1
# Twentieth Century Fox Film Corporation|Blue Sky Studios - Number of Films: 1
# Twisted Pictures - Number of Films: 1
# Square USA - Number of Films: 1
# Original Film - Number of Films: 1
# DNA - Number of Films: 1
# DeepStudios - Number of Films: 1
# Arc Productions - Number of Films: 1
# Sony Pictures Animation - Number of Films: 1
# The Directors Bureau|Hi! Production - Number of Films: 1
# Haut et Court|Parallel Film Productions|Fox International Productions (FIP) - Number of Films: 1
# Eros International - Number of Films: 1
# FidÃ©litÃ© Productions|StudioCanal|TF1 Films Production|Bankable - Number of Films: 1
# Sky Movies - Number of Films: 1
# Blinky Productions - Number of Films: 1
# Lucasfilm - Number of Films: 1
# Theatre Junkies - Number of Films: 1
# DreamWorks Home Entertainment - Number of Films: 1
# Lucasfilm|Pixar Animation Studios - Number of Films: 1
# CinÃ©TÃ© Filmproductie BV - Number of Films: 1
# Snowman Enterprise - Number of Films: 1
# WT Canada Productions - Number of Films: 1
# On The Corner Films|We Came, We Saw, We Conquered Studios - Number of Films: 1
# Aardman Animations - Number of Films: 1
# Buena Vista Home Entertainment - Number of Films: 1
# Norddeutscher Rundfunk (NDR) - Number of Films: 1
# Lee Mendelson Film Productions|Bill Melendez Productions|United Feature Syndicate (UFS) - Number of Films: 1
# Annuit Coeptis Entertainment Inc.|Annuit Coeptis Entertainment II - Number of Films: 1
# Fuzzy Logic Pictures - Number of Films: 1
# Gracie Films - Number of Films: 1
# Eskoria Films - Number of Films: 1
# DC Comics - Number of Films: 1
# Alfred Image Works - Number of Films: 1
# Globo Filmes - Number of Films: 1
# Platige Image - Number of Films: 1
# Island 23 Films - Number of Films: 1
# Warner Premiere - Number of Films: 1
# H5|Autour de Minuit Productions|Little Minx Films - Number of Films: 1
# Aniplex|Anime Innovation Tokyo - Number of Films: 1
# RatPac Entertainment|Melco-Crown Entertainment (MCE) - Number of Films: 1
# DC Comics|Warner Premiere - Number of Films: 1
# Warner Bros. Pictures - Number of Films: 1
# Titmouse - Number of Films: 1
# Netflix - Number of Films: 1
# Adi Shankar Production - Number of Films: 1
# Unframed USA - Number of Films: 1
# Toma 78 - Number of Films: 1
# Filmauro - Number of Films: 1
# Chaotic Rampage American Pictures - Number of Films: 1
# 20th Century Fox|Blue Sky Studios - Number of Films: 1
# DisneyToon Studios|Walt Disney Animation Studios|Prana Animation Studios - Number of Films: 1
# A+E Studios|Jane Startz Productions - Number of Films: 1
# DC Comics|Warner Bros. Animation|Warner Premiere|DC Entertainment - Number of Films: 1
# Access Motion Pictures - Number of Films: 1
# Moonbot Studios - Number of Films: 1
# Zealous Creative - Number of Films: 1
# Disney - Number of Films: 1
# Ubisoft - Number of Films: 1
# Arrowstorm Entertainment|Camera 40 Productions|Bellpond Films - Number of Films: 1
#
# The most repeated production company name:
# Pixar Animation Studios

# %% [markdown]
# سوال شونزدهم: پنج فیلم برتر از نظر بیشترین تعداد رای دهنده کدام فیلم هاست؟

# %%
sorted_df = df.sort_values(by='vote_count', ascending=False)
top_five = sorted_df.head(5)
print("Top five movies with the highest vote_count:")
for index, row in top_five.iterrows():
    print(f"{row['original_title']} - Vote Count: {row['vote_count']}")
# Out:
# Top five movies with the highest vote_count:
# Inception - Vote Count: 9767
# The Avengers - Vote Count: 8903
# Avatar - Vote Count: 8458
# The Dark Knight - Vote Count: 8432
# Django Unchained - Vote Count: 7375

# %% [markdown]
# پنج فیلم برتر از نظر نمره مخاطبین کدام فیلم هاست؟

# %%
filtered_df1 = df[df['vote_count'] >= 1000]
sorted_dff = filtered_df1.sort_values(by='vote_average', ascending=False)
top_five = sorted_dff.head(5)
print("Top five movies with the highest score (with at least 1000 votes each):")
for index, row in top_five.iterrows():
    print(f"{row['original_title']} - Vote Average: {row['vote_average']} (Vote Count: {row['vote_count']})")
# Out:
# Top five movies with the highest score (with at least 1000 votes each):
# The Shawshank Redemption - Vote Average: 8.4 (Vote Count: 5754)
# The Godfather - Vote Average: 8.3 (Vote Count: 3970)
# Whiplash - Vote Average: 8.2 (Vote Count: 2372)
# Pulp Fiction - Vote Average: 8.1 (Vote Count: 5343)
# Forrest Gump - Vote Average: 8.1 (Vote Count: 4856)
